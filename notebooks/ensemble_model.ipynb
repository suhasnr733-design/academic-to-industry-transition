# %%
# notebooks/ensemble_model.ipynb

from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
import joblib

# Load best models
best_rf = joblib.load('../data/models/best_rf.pkl')
best_xgb = joblib.load('../data/models/best_xgb.pkl')

# Create Stacking Ensemble
base_models = [
    ('rf', best_rf),
    ('xgb', best_xgb),
    ('svm', SVC(kernel='rbf', probability=True))
]

stacking_model = StackingClassifier(
    estimators=base_models,
    final_estimator=LogisticRegression(),
    cv=5
)

stacking_model.fit(X_train_scaled, y_train)
y_pred = stacking_model.predict(X_test_scaled)

print(f"Ensemble Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print(f"Ensemble F1: {f1_score(y_test, y_pred):.4f}")

# Save ensemble
joblib.dump(stacking_model, '../data/models/ensemble_model.pkl')
joblib.dump(scaler, '../data/models/scaler.pkl')
joblib.dump(feature_columns, '../data/models/feature_columns.pkl')
print("✅ Ensemble model created and saved!")
